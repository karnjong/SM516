# %% [markdown]
# ## CHAPTER 1 OPTIMIZATION PROBLEMS

# %% [markdown]
# INTRODUCTION
#
#     - Optimization problems deal with finding the best way to do a problem, subject to any constrains or restriction on the actions that may be taken to accomplish the task
#     - Many problems can be possed as optimization problem
#
# EXAMPLE OF OPTIMIZATION PROBLEMS
#
#     - Choosing an investing portfolio to minimize risk or to maximize the return
#     - Maximizing the profit obtained from selling different products
#     - The design of the shape of an aircraft to maximize the aircraft performance of minimize the estimation cost
#
# THE STANDARD FORM OF THE OPTIMIZATION PROBLEMS
#
#     - minimize : f(x) :
#         - subject to :
#     - column X is a column vector with n elements and X tranpose is a new vector
# $$
# x(vector)
# =
# \left[
# \begin{array}{rrr}
# x1 \\
# x2 \\
# . \\
# . \\
# . \\
# xn \\
# \end{array}
# \right]
# $$
#
# $$
# x tranpose(vector)
# =
# \left[
# \begin{array}{rrr}
# x1 & x2 &...& xn \\
# \end{array}
# \right]
# $$

# %% [markdown]
# THE EUCLIDEAN LENGTH : ||x|| or $$ x  \in \Bbb{R}$$
#
#     - EXAMPLE
# $$
# x(vector)
# =
# \left[
# \begin{array}{rrr}
# 1 \\
# 2 \\
# \end{array}
# \right]
# $$
#  Thus, the euclidean length is

# %% [markdown]
# The function f(x) is called the objective function
#
#     - The set is a subset of n-dimensional eucilean space Rn
#     - that is called the feasible region
#     1. If consists of all pints x which satisfy all the constrains
#     2. If , the problem is constrained
# Any problem can be converted to be a  minimization problem by using negative sign
# where, maxf(x) and minf(x) have the same solution

# %% [markdown]
# **EX1 POST OFFICE PARCEL PROBLEM**
#
# The length plus the girth of any parcel sent through the post must not exceed 1.8 meters and the girth as the distanc perpendicular to the length around the parcel
#     What are the dimension of the parcel with rectangular sides of the largest volume that could be sent through the post?
#
#   **Solve**
#
#   <img src='https://dp57v9mrmcue2.cloudfront.net/wp-content/uploads/2019/08/IMG_6857-512x364.jpeg'  width = 150 align ='left'>
# <div align ='center'> let x1 = length</div>
# <div align ='center'> let x2 = width </div>
# <div align ='center'> let x3 = depth </div>

# %% [markdown]
# **OBJECTIVE FUNCTION** : to maximize volume
#
#                         f(x) = (x1)(x2)(x3)
#
# **SUBJECT TO** :
#
#                  1) x1 >= 0
#                  2) x2 >= 0
#                  3) x3 >= 0
#                  4) x1+2x2+2x3 <= 1.8
#                  5) x1 >= x3
#                  6) x1 >= x2
# to minimize volume
#
#                 f(x) = -(x1)(x2)(x3)
#
# **SUBJECT TO** :
#
#                  1) -x1 <= 0
#                  2) -x2 <= 0
#                  3) -x3 <= 0
#                  4) x1+2x2+2x3 - 1.8 <= 0
#                  5) x3-x1 <= 0
#                  6) x2-x1 <= 0

# %% [markdown]
# **EX2 FROM SHEET**
# Data FROM THIS PROBLEM
#
# 1. Property trust
#     - To invest at least 20% and at most 80%
#     - The predicted return is 5% per annum
# 2. Share trust
#     - To invest at least 10%
#     - The predicted return is 12% per annum
#
# **Solve**
# Let
#
#     - x1 denoted proportion of assets are allocated to the property trust
#     - x2 denoted proportion of assets are allocated to the share trust
#
# contraints:
#
#             1. 0 <= x1+x2 <= 1
#             2. 0.2 <= x1 <= 0.8
#             3. 0.1 <= x2 <= 1
#             4. 0 <= x1 <= 1
#
# Find feasible region
# is
# $$ x
# \in \Bbb{R}$$
# $$
# \left[
# \begin{array}{rrr}
# 0.2\\
# 0.1 \\
# \end{array}
# \right]
# <=
# \left[
# \begin{array}{c}
# x1\\
# x2\\
# \end{array}
# \right]
# <=
# \left[
# \begin{array}{c}
# 0.8\\
# 1\\
# \end{array}
# \right]
# $$

# %% [markdown]
# <img src="picture/op1.jpg" width = 300 align ='center'>

# %% [markdown]
# 1.1) Formulate a minimixe problem that finds the asset allocation that maximizes the investors predicted return
#
# **Solve**
#
# **OBJECTIVE FUNCTION** :maximize the predicted return
#
#             maxf(x) ; f(x) = 0.05x1+0.12x2
#  $$
#  r
#  =
# \left[
# \begin{array}{rrr}
# 0.05\\
# 0.12 \\
# \end{array}
# \right]
# ,
# x
# =
# \left[
# \begin{array}{rrr}
# x1\\
# x2 \\
# \end{array}
# \right]
# $$
#
# Thus, fr(x) = r(transpose)X = 0.05x1+0.12x2
#
# **SUBJECT TO** : x
#
# 1.2) Formulate a minimize problem that finds the asset allocation that minimizes the investors risk
# **Solve**
#
# **OBJECTIVE FUNCTION** : minimize the investors risk
#
#                      minfe(x) ; fe(x) = x(transpose)Cx
# $$
# x(transpose)Cx
#  =
# \left[
# \begin{array}{rrr}
# x1 & x1\\
# \end{array}
# \right]
# \left[
# \begin{array}{rrr}
# 0.3 & -0.2\\
# -0.2 & 0.45\\
# \end{array}
# \right]
# \left[
# \begin{array}{rrr}
# x1\\
# x2\\
# \end{array}
# \right]
# =
# 0.3x1^2-0.4x1x2+0.45x2^2
# $$
#
# **SUBJECT TO** : x
#
# 1.3) Formulate a minimization problem that finds the asset allocation that minimizes a weighted combination of the expected return and the risk
#
#
# **solve**
#
#             1. The investor has 2 completing objectives
#                 1.1 To wish maximize their returns
#                 1.2 While at the same time minimizing their risks
#             2. This is a multi-objective optimization problem
#                 2.1 It may be possed by taking a weight sum of the 2 objectives
#                 2.2 When the weight are nonnegative
#                     - aading up to 1
#
# **OBJECTIVE FUNCTION** : a1fr(x)+a2fe(x)
#
#                     1. a1, a2>=0
#                     2. a1+a2 =1 >> a1 = 1-a2
#                 Thus, (1-a2)fr(x)+a2fe(x)
#                 min risk :
#                 -betafr(x)+(1+beta)fr(x)
#                 min fbeta(x) = -betafr(x)+(1+beta)fe(x)
# **SUBJECT TO** : $$ x  \in feasible\;\;region $$

# %% [markdown]
# **EX3** Consider a mortgage team with $100,000,000 to finance various investments. There are 5 categories of loans, each loan with an associated return and risk(1-10, 1 best)

# %% [markdown]
# <img src="picture/op2.jpg" width = 500 align ='center'>

# %% [markdown]
# Any uninterested money goes-into a saving account with no risk and 3% return. The goal for the mortgage team is to allocate the money to the categories for as to:
#
#         a. Maximize the average return(that means return)
#         b. Have an average risk no more than 5 call average and fractions take over the invested money but not over the saving account
#         c. Invest at least 20% in commercial loan
#         d. The amount in second mortgage and personal loans combined should be no higher than the amount in the first mortgage
#
# **Solve**
#
# let
#
#             - xi be the amount invested in investment i for i = 1,2,...,5
#             - x6 be the amount invested in saving account
# **OBJECTIVE FUNCTION** : Maximize the return
#
#                 maxfr(x) ; fr(x) = 0.09x1+0.12x2+0.15x3+0.08x4+0.06x5+0.03x6
# **SUBJECT TO** :
#
#             1. (3x1+6x2+8x3+2x4+x5)/(x1+x2+x3+x4+x5) <= 5
#             2. the sum of xi = 100,000,000
#             3. x4 >= 0.20(x1+x2+x3+x4+x5)
#             4. x2+x3<=x1
# **ANS**   Return 12% by investing 40% of the assetes in first mortgage, 40% in personal loans and 20% in commercial loans
