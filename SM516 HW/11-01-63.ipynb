# %% [markdown]
# # <center>SM516 การโปรแกรมขั้นสูง

# %% [markdown]
# <img src="Karn.jpg" width = 60 align ='right'>

# %% [markdown]
# <div align ='right'> กาญจนา $\;\;$ จงจิตร์</div>
# <div align ='right'> วิศวกรรมเคมี มธ.</div>
# <div align ='right'> 11 มกราคม 2563</div>

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('pAnK1y7qjuE')

# %%
from IPython.display import Video

Video("xxx.mp4", width=600)
# Out:
# <video src="xxx.mp4" controls  width="600" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# $\alpha$ bdzzkbczbczkd
# $$ ax^2 +bx +c =0 \tag{1}$$

# %% [markdown]
# $$x = \frac{-b\pm \sqrt{b^2 -4ac}}{2a} \tag{2}$$

# %% [markdown]
# $$
# \left[
# \begin{array}{rrr}
# -1 & 0 & 1 \\
# -2 & -3 & 4 \\
# 3 & 12 & 256 \\
# \end{array}
# \right]
# \left[
# \begin{array}{c}
# x\\y\\z
# \end{array}
# \right]
# =
# \left[
# \begin{array}{c}
# 8\\7\\12
# \end{array}
# \right]
# $$

# %% [markdown]
# ## การวัดผล
#
#   1. กิจกรรมในห้องเรียน 40%
#       - สมุดจด 30%
#       - การโปรแกรม 10%
#   1. การบ้าน 20% $\rightarrow$ จัดเก็บลงบน **_flashdrive_** ส่งในวันสอบปลายภาค
#   1. สอบปลายภาค 60% ***(ได้คะแนนน้อยกว่า 15% ให้เรียนใหม่)***

# %% [markdown]
# ## การติดตั้งโปรแกรม
#
# 1. [WinPython](https://winpython.github.io/)
# ![](https://winpython.github.io/images/winpython_title.png)

# %% [markdown]
# ## เนื้อหา
#
# 1. Python
#     - Installation
#     - Jupyter Notebook
#         - Markdown
#             - Markdown
#             - Html
#             - Latex
#     - Object oriented Programming(OOP)
#         - Object
#             - Single Object
#             - Container
#             - OOP
#         - Expression
#             - Operators
#             - Logic
#         - Commands
#             - Conditions
#             - Repetition
#         - Module
#             - Packages
#                 - math and cmath
#                 - numpy
#                 - matplotlib
#                 - pandas
#                 - sympy
#         - Program
#             - Jupyter notebook/Jupyter Lab
#             - vscode
#             - pyCharm
#
#  * Repository and Code Version Control (GitHub)
# 1. Python for Finance
# 1. Python for Statistics
#
# 1. R Programming

# %% [markdown]
# ## เอกสารอ้างอิง
#
# - หนังสือหลักสำหรับ Python คือ Mark Lutz [Learning Python 5th Edition](https://www.amazon.com/Learning-Python-5th-Mark-Lutz/dp/1449355730/ref=sr_1_1?crid=35YR803PUJAP7&keywords=mark+lutz&q##
# - [copy] (Mark Lutz Learning Python, 5th Edition.pdf )

# %% [markdown]
# <u>เอกสาร</u>
